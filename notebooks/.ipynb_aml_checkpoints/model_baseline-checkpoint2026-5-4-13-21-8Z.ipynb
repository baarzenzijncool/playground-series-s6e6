# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import pathlib

COMP_DIR = pathlib.Path('../data/')

pd.read_csv(COMP_DIR / 'train.csv', index_col='id')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 import pathlib
#       3
#       4 COMP_DIR = pathlib.Path('../data/')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import torch

device = "gpu" if torch.cuda.is_available() else "cpu"
device
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import torch
#       2
#       3 device = "gpu" if torch.cuda.is_available() else "cpu"
#       4 device
#
# ModuleNotFoundError: No module named 'torch'

# %%
torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 torch.cuda.is_available()
#
# NameError: name 'torch' is not defined

# %%
import pandas as pd
import numpy as np

np.zeros(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4 np.zeros(10)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
1+1
