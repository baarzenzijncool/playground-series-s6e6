# %%
# %load_ext cudf.pandas

# %%
import pathlib
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

COMP_DIR = pathlib.Path("../data/")

# COMPETITION DATA
train = pd.read_csv(COMP_DIR / "train.csv", index_col="id")
test = pd.read_csv(COMP_DIR / "test.csv", index_col="id")
sample_submission = pd.read_csv(COMP_DIR / "sample_submission.csv")

train.columns = train.columns.str.lower()
test.columns = test.columns.str.lower()

print(train.shape, test.shape)
# Out:
# (577347, 11) (247435, 10)

# %%
train.head(5)
# Out:
#          alpha      delta          u          g          r          i  \
# id
# 0   147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#             z  redshift spectral_type galaxy_population   class
# id
# 0   18.621057  0.408982             M      Red_Sequence  GALAXY
# 1   16.786433  0.157976             M      Red_Sequence  GALAXY
# 2   20.557366  2.823770           O/B        Blue_Cloud     QSO
# 3   17.914952  0.536099             M      Red_Sequence  GALAXY
# 4   17.616185  0.555761             M      Red_Sequence  GALAXY

# %%
ohe_df = pd.get_dummies(train[["spectral_type", "galaxy_population"]], drop_first=True, dtype="category")
ohe_df.columns = ohe_df.columns.str.lower()

train = pd.concat([train, ohe_df], axis=1)
train = train.drop(columns=["spectral_type", "galaxy_population"])

# %%
TARGET = "class"
NUM_COLS = [c for c in train.select_dtypes(include=["number"]).columns]
CAT_COLS = [c for c in train.columns if c not in NUM_COLS + [TARGET]]

# %%
TARGET_MAPPING = {
    "GALAXY": 0,
    "QSO": 1,
    "STAR": 2
}

train[TARGET] = train[TARGET].map(TARGET_MAPPING)

# %%
XGB_PARAMS = {
    "objective": "multi:softprob",
    "num_class": 3,
    "tree_method": "hist",
    "device": "cuda",
    "n_estimators": 1000,
    "learning_rate": 0.01,
    "max_depth": 6,
    "min_child_weight": 10,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "reg_alpha": 0.1,
    "random_state": 42,
    "enable_categorical": True
}

# %%
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.utils.class_weight import compute_sample_weight

skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

X = train[NUM_COLS + CAT_COLS]
y = train[TARGET]

oof_probs = np.zeros((X.shape[0], 3))

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):

    X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    model = XGBClassifier(
        **XGB_PARAMS
    )

    model.fit(X_train, y_train)

    oof_probs[val_idx] = model.predict_proba(X_val)
    oof_score = balanced_accuracy_score(y_val, np.argmax(oof_probs[val_idx], axis=1))

    print(f'Fold {fold+1} Balanced Accuracy: {oof_score:.5f}')

oof_probs /= 5

oof_score_full = balanced_accuracy_score(y, np.argmax(oof_probs, axis=1))

print(f"Full OOF balanced_accuracy: {oof_score_full:.5f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 24
#      20     model = XGBClassifier(
#      21         **XGB_PARAMS
#      22     )
#      23
# ---> 24     model.fit(X_train, y_train)
#      25
#      26     oof_probs[val_idx] = model.predict_proba(X_val)
#      27     oof_score = balanced_accuracy_score(y_val, np.argmax(oof_probs[val_idx], axis=1))
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/sklearn.py:1787, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1784 model, feature_types = get_model_categories(X, model, self.feature_types)
#    1786 evals_result: EvalsLog = {}
# -> 1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    1790     y=y,
#    1791     group=None,
#    1792     qid=None,
#    1793     sample_weight=sample_weight,
#    1794     base_margin=base_margin,
#    1795     feature_weights=feature_weights,
#    1796     eval_set=eval_set,
#    1797     sample_weight_eval_set=sample_weight_eval_set,
#    1798     base_margin_eval_set=base_margin_eval_set,
#    1799     eval_group=None,
#    1800     eval_qid=None,
#    1801     create_dmatrix=self._create_dmatrix,
#    1802     enable_categorical=self.enable_categorical,
#    1803     feature_types=feature_types,
#    1804 )
#    1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    (...)   1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/sklearn.py:700, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     695 """Convert array_like evaluation matrices into DMatrix. Perform sanity checks on the
#     696 way.
#     697
#     698 """
#     699 # Feature_types contains the optional reference categories from the booster object.
# --> 700 train_dmatrix = create_dmatrix(
#     701     data=X,
#     702     label=y,
#     703     group=group,
#     704     qid=qid,
#     705     weight=sample_weight,
#     706     base_margin=base_margin,
#     707     feature_weights=feature_weights,
#     708     missing=missing,
#     709     enable_categorical=enable_categorical,
#     710     feature_types=feature_types,
#     711     ref=None,
#     712 )
#     714 n_validation = 0 if eval_set is None else len(eval_set)
#     715 if hasattr(train_dmatrix, "get_categories"):
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/sklearn.py:1262, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1260     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1261         pass
# -> 1262 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/core.py:976, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     973     assert self.handle is not None
#     974     return
# --> 976 handle, feature_names, feature_types = dispatch_data_backend(
#     977     data=data,
#     978     missing=self.missing,
#     979     threads=self.nthread,
#     980     feature_names=feature_names,
#     981     feature_types=feature_types,
#     982     enable_categorical=enable_categorical,
#     983     data_split_mode=data_split_mode,
#     984 )
#     985 assert handle is not None
#     986 self.handle = handle
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/data.py:1429, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical, data_split_mode)
#    1427     data = pd.DataFrame(data)
#    1428 if _is_pandas_df(data):
# -> 1429     return _from_pandas_df(
#    1430         data=data,
#    1431         enable_categorical=enable_categorical,
#    1432         missing=missing,
#    1433         nthread=threads,
#    1434         feature_names=feature_names,
#    1435         feature_types=feature_types,
#    1436         data_split_mode=data_split_mode,
#    1437     )
#    1438 if _is_cudf_df(data) or _is_cudf_ser(data):
#    1439     return _from_cudf_df(
#    1440         data=data,
#    1441         missing=missing,
#    (...)   1445         enable_categorical=enable_categorical,
#    1446     )
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/data.py:706, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types, data_split_mode)
#     696 def _from_pandas_df(
#     697     *,
#     698     data: "PdDataFrame",
#    (...)    704     data_split_mode: DataSplitMode = DataSplitMode.ROW,
#     705 ) -> DispatchedDataBackendReturnType:
# --> 706     df, feature_names, feature_types = _transform_pandas_df(
#     707         data, enable_categorical, feature_names, feature_types
#     708     )
#     710     handle = ctypes.c_void_p()
#     711     _check_call(
#     712         _LIB.XGDMatrixCreateFromColumnar(
#     713             df.array_interface(),
#    (...)    718         )
#     719     )
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/data.py:674, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     668 feature_names, feature_types = pandas_feature_info(
#     669     data, meta, feature_names, feature_types, enable_categorical
#     670 )
#     672 arrays = pandas_transform_data(data)
#     673 return (
# --> 674     PandasTransformed(arrays, ref_categories=ref_categories),
#     675     feature_names,
#     676     feature_types,
#     677 )
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/data.py:627, in PandasTransformed.__init__(self, columns, ref_categories)
#     624 for col in self.columns:
#     625     if _is_df_cat(col):
#     626         # Categorical column
# --> 627         jnames, jcodes, buf = pd_cat_inf(col.categories, col.codes)
#     628         temporary_buffers.append(buf)
#     629         aitfs.append((jnames, jcodes))
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/_data_utils.py:466, in pd_cat_inf(cats, codes)
#     463     return offsets.astype(np.int32), values
#     465 # String index type
# --> 466 name_offsets, name_values = npstr_to_arrow_strarr(cats.values)
#     467 name_offsets, _ = _ensure_np_dtype(name_offsets, np.int32)
#     468 joffsets = array_interface_dict(name_offsets)
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/xgboost/_data_utils.py:455, in pd_cat_inf.<locals>.npstr_to_arrow_strarr(strarr)
#     451         strarr = np.asarray(strarr, dtype=object)
#     453 lenarr = np.vectorize(len)
#     454 offsets = np.cumsum(
# --> 455     np.concatenate([np.array([0], dtype=np.int64), lenarr(strarr)])
#     456 )
#     457 if strarr.dtype.kind == "S":
#     458     str_list = [s.decode("utf-8") for s in strarr.tolist()]
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:2518, in vectorize.__call__(self, *args, **kwargs)
#    2515     self._init_stage_2(*args, **kwargs)
#    2516     return self
# -> 2518 return self._call_as_normal(*args, **kwargs)
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:2511, in vectorize._call_as_normal(self, *args, **kwargs)
#    2508     vargs = [args[_i] for _i in inds]
#    2509     vargs.extend([kwargs[_n] for _n in names])
# -> 2511 return self._vectorize_call(func=func, args=vargs)
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:2596, in vectorize._vectorize_call(self, func, args)
#    2594     res = func()
#    2595 else:
# -> 2596     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2597     # gh-29196: `dtype=object` should eventually be removed
#    2598     args = [asanyarray(a, dtype=object) for a in args]
#
# File ~/.venvs/python-311-kaggle/.venv/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:2556, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2552     raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2553                      'unless `otypes` is set')
#    2555 inputs = [arg.flat[0] for arg in args]
# -> 2556 outputs = func(*inputs)
#    2558 # Performance note: profiling indicates that -- for simple
#    2559 # functions at least -- this wrapping can almost double the
#    2560 # execution time.
#    2561 # Hence we make it optional.
#    2562 if self.cache:
#
# TypeError: object of type 'numpy.bool' has no len()
